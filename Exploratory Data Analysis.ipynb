# %%
import pandas as pd 
import numpy as np

# %%
# checking the items in the working directory  .
# !ls
# Out:
# Data                            Exploratory Data Analysis.ipynb

# %%
#loading the data into workspace 
train = pd.read_csv("Data/train.csv" )
test = pd.read_csv("Data/test.csv")

# %%
#basic info 
train.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %% [markdown]
# ## There seems to be too many features in the data, lets get the number of columns and the size of the dataset.

# %%
len(train.columns)
# Out:
# 202

# %%
#more infp
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %%
sum(x.dtypes == 'categorical')
#we can see that there are no categorical features in the training feature set .
# Out:
# 0

# %%
#sample of the dataset 
train.sample(5 )
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 51750    train_51750       0   5.3894 -6.5740  11.6215  5.8926  11.6626
# 83900    train_83900       0   5.4317 -9.6728  10.6561  9.0188   8.3656
# 94126    train_94126       1   8.3419 -6.0586  10.6031  4.0758  12.4276
# 142388  train_142388       0  10.3328  4.9189  11.0386  7.8488  12.5038
# 75194    train_75194       0   8.7669  1.6024  12.4252  3.4194  10.4496
#
#          var_5   var_6    var_7   ...     var_190  var_191  var_192  var_193  \
# 51750  -7.3430  5.6401  17.0571   ...      7.1072   4.6513   0.1452   6.1001
# 83900   7.7473  4.8228  14.6463   ...     -2.2406  10.7343   0.6463   3.4937
# 94126   3.8304  3.7546  18.7721   ...      3.6490  15.5367   3.1791   5.5421
# 142388 -6.1825  4.8635  23.1931   ...      3.0147   7.7841   1.2485  -0.1025
# 75194   3.0747  4.4744  20.0836   ...     10.4069   6.0146   1.6320   0.4213
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# ...

# %%
#this separates the target and independent variables .
x = train.iloc[ :,train.columns != 'target']
y = train.iloc[:,train.columns == 'target'].astype('float64')

# %%
# percentage of the imbalance in the data 
(train['target'].value_counts()/len(train))*100
# Out:
# 0    89.951
# 1    10.049
# Name: target, dtype: float64

# %%
#breaking the feature variables to smaller sets so as to test functions on it quickly 
df = x.sample(100)

# %%
#Plotting the correlation curves to take out the highly correalted ones 
c = train.corr()
c
# Out:
#            target     var_0     var_1     var_2     var_3     var_4     var_5  \
# target   1.000000  0.052390  0.050343  0.055870  0.011055  0.010915  0.030979
# var_0    0.052390  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046
# var_1    0.050343 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902
# var_2    0.055870  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569
# var_3    0.011055  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253
# var_4    0.010915  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368
# var_5    0.030979  0.003046 -0.000902  0.001569  0.003253 -0.001368  1.000000
# var_6    0.066731  0.006983  0.003258  0.000883 -0.000774  0.000049  0.002588
# var_7   -0.003025  0.002429  0.001511 -0.000991  0.002500  0.004549 -0.000995
# var_8    0.019584  0.004962  0.004098  0.002648  0.003553  0.001194  0.000147
# var_9   -0.042805 -0.002613 -0.000832 -0.001932 -0.000826 -0.000918 -0.005279
# ...

# %%
#making up a small subset so that the function can be tested .
c1 = c.iloc[:3, :3]

# %%
c1
# Out:
#           target     var_0     var_1
# target  1.000000  0.052390  0.050343
# var_0   0.052390  1.000000 -0.000544
# var_1   0.050343 -0.000544  1.000000

# %%
c1.iloc[1][2]
# Out:
# -0.0005436992424820352

# %%
columns   = np.full(( c.shape[0],),True , dtype = bool)

# %%
c.shape
# Out:
# (201, 201)

# %%
#writing a function to elimiante higly correlated variables .
for i in range(c.shape[0]):
    for j in range(i+1,c.shape[0]):
        if c.iloc[i,j] >= 0.9:
            if l[j]:
                l[j] = False
        else:
             pass

# %%
#Selecting the columns that are note highly correlated 
X = x.iloc[:,columns]

# %%
len(X.columns)
# Out:
# 201

# %% [markdown]
# ### It looks like all the variables are not highly correlated , and hence all of them can be used to build a model .

# %%
len(X.dtypes == 'float64')
#all the variables seem to be numerical .
# Out:
# 201

# %% [markdown]
# ### Plotting the relation between the variables .

# %%
# Out:
# <bound method DataFrame.info of              ID_code    var_0   var_1    var_2    var_3    var_4    var_5  \
# 0            train_0   8.9255 -6.7863  11.9081   5.0930  11.4607  -9.2834
# 1            train_1  11.5006 -4.1473  13.8588   5.3890  12.3622   7.0433
# 2            train_2   8.6093 -2.7457  12.0805   7.8928  10.5825  -9.0837
# 3            train_3  11.0604 -2.1518   8.9522   7.1957  12.5846  -1.8361
# 4            train_4   9.8369 -1.4834  12.8746   6.6375  12.2772   2.4486
# 5            train_5  11.4763 -2.3182  12.6080   8.6264  10.9621   3.5609
# 6            train_6  11.8091 -0.0832   9.3494   4.2916  11.1355  -8.0198
# 7            train_7  13.5580 -7.9881  13.8776   7.5985   8.6543   0.8310
# 8            train_8  16.1071  2.4426  13.9307   5.6327   8.8014   6.1630
# 9            train_9  12.5088  1.9743   8.8960   5.4508  13.6043 -16.2859
# 10          train_10   5.0702 -0.5447   9.5900   4.2987  12.3910 -18.8687
# ...
